# %% [markdown]
# Nama : Credenda Mirandantons

# %% [markdown]
# ## NO.8

# %%
#maodule
# - function
# - docstring
# - memanfaatkan conditional statement / iterasi
# - terdapat handling 

# membuat perhitungan pytagoras

# %%
from myJ import game

# %%
game(51)
# Out:
# 'i is greater than 15'
